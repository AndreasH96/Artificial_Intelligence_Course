# %%
import poker_environment as pe_
from poker_environment import AGENT_ACTIONS, BETTING_ACTIONS
import copy

"""
Player class
"""
class PokerPlayer(object):
    def __init__(self, current_hand_=None, stack_=300, action_=None, action_value_=None):
        self.current_hand = current_hand_
        self.current_hand_type = []
        self.current_hand_strength = []
        self.stack = stack_
        self.action = action_
        self.action_value = action_value_

    """
    identify agent hand and evaluate it's strength
    """
    def evaluate_hand(self):
        self.current_hand_type = pe_.identify_hand(self.current_hand)
        self.current_hand_strength = pe_.Types[self.current_hand_type[0]]*len(pe_.Ranks) + pe_.Ranks[self.current_hand_type[1]]

    """
    return possible actions, fold if there is not enough money...
    """
    def get_actions(self):
        actions_ = []
        for _action_ in AGENT_ACTIONS:
            if _action_[:3] == 'BET' and int(_action_[3:])>=(self.stack):
                actions_.append('FOLD')
            else:
                actions_.append(_action_)
        return set(actions_)

"""
Game State class
"""
class GameState(object):
    def __init__(self,
                 nn_current_hand_=None,
                 nn_current_bidding_=None,
                 phase_ = None,
                 pot_=None,
                 acting_agent_=None,
                 parent_state_=None,
                 children_state_=None,
                 agent_=None,
                 opponent_=None):

        self.nn_current_hand = nn_current_hand_
        self.nn_current_bidding = nn_current_bidding_
        self.phase = phase_
        self.pot = pot_
        self.acting_agent = acting_agent_
        self.parent_state = parent_state_
        self.children = children_state_
        self.agent = agent_
        self.opponent = opponent_
        self.showdown_info = None

    """
    draw 10 cards randomly from a deck
    """
    def dealing_cards(self):
        agent_hand, opponent_hand = pe_.generate_2hands()
        self.agent.current_hand = agent_hand
        self.agent.evaluate_hand()
        self.opponent.current_hand = opponent_hand
        self.opponent.evaluate_hand()
        #self.showdown_info = None

    """
    draw 10 cards from a fixed sequence of hands
    """
    def dealing_cards_fixed(self):
        self.agent.current_hand = pe_.fixed_hands[self.nn_current_hand][0]
        self.agent.evaluate_hand()
        self.opponent.current_hand = pe_.fixed_hands[self.nn_current_hand][1]
        self.opponent.evaluate_hand()

    """
    SHOWDOWN phase, assign pot to players
    """
    def showdown(self):

        if self.agent.current_hand_strength == self.opponent.current_hand_strength:
            self.showdown_info = 'draw'
            if self.acting_agent == 'agent':
                self.agent.stack += (self.pot - 5) / 2. + 5
                self.opponent.stack += (self.pot - 5) / 2.
            else:
                self.agent.stack += (self.pot - 5) / 2.
                self.opponent.stack += (self.pot - 5) / 2. + 5
        elif self.agent.current_hand_strength > self.opponent.current_hand_strength:
            self.showdown_info = 'agent win'
            self.agent.stack += self.pot
        else:
            self.showdown_info = 'opponent win'
            self.opponent.stack += self.pot

    # print out necessary information of this game state
    def print_state_info(self):

        print('************* state info **************')
        print('nn_current_hand', self.nn_current_hand)
        print('nn_current_bidding', self.nn_current_bidding)
        print('phase', self.phase)
        print('pot', self.pot)
        print('acting_agent', self.acting_agent)
        print('parent_state', self.parent_state)
        print('children', self.children)
        print('agent', self.agent)
        print('opponent', self.opponent)

        if self.phase == 'SHOWDOWN':
            print('---------- showdown ----------')
            print('agent.current_hand', self.agent.current_hand)
            print(self.agent.current_hand_type, self.agent.current_hand_strength)
            print('opponent.current_hand', self.opponent.current_hand)
            print(self.opponent.current_hand_type, self.opponent.current_hand_strength)
            print('showdown_info', self.showdown_info)

        print('----- agent -----')
        print('agent.current_hand',self.agent.current_hand)
        print('agent.current_hand_type',self.agent.current_hand_type)
        print('agent.current_hand_strength',self.agent.current_hand_strength)
        print('agent.stack',self.agent.stack)
        print('agent.action',self.agent.action)
        print('agent.action_value',self.agent.action_value)

        print('----- opponent -----')
        print('opponent.current_hand', self.opponent.current_hand)
        print('opponent.current_hand_type',self.opponent.current_hand_type)
        print('opponent.current_hand_strength',self.opponent.current_hand_strength)
        print('opponent.stack',self.opponent.stack)
        print('opponent.action',self.opponent.action)
        print('opponent.action_value',self.opponent.action_value)
        print('**************** end ******************')

# copy given state in the argument
def copy_state(game_state):
    _state = copy.copy(game_state)
    _state.agent = copy.copy(game_state.agent)
    _state.opponent = copy.copy(game_state.opponent)
    return _state

"""
successor function for generating next state(s)
"""
def get_next_states(last_state):

    if last_state.phase == 'SHOWDOWN' or last_state.acting_agent == 'opponent' or last_state.phase == 'INIT_DEALING':

        # NEW BETTING ROUND, AGENT ACT FIRST

        states = []

        for _action_ in last_state.agent.get_actions():

            _state_ = copy_state(last_state)
            _state_.acting_agent = 'agent'

            if last_state.phase == 'SHOWDOWN' or last_state.phase == 'INIT_DEALING':
                _state_.dealing_cards()

            if _action_ == 'CALL':

                _state_.phase = 'SHOWDOWN'
                _state_.agent.action = _action_
                _state_.agent.action_value = 5
                _state_.agent.stack -= 5
                _state_.pot += 5

                _state_.showdown()

                _state_.nn_current_hand += 1
                _state_.nn_current_bidding = 0
                _state_.pot = 0
                _state_.parent_state = last_state
                states.append(_state_)

            elif _action_ == 'FOLD':

                _state_.phase = 'SHOWDOWN'
                _state_.agent.action = _action_
                _state_.opponent.stack += _state_.pot

                _state_.nn_current_hand += 1
                _state_.nn_current_bidding = 0
                _state_.pot = 0
                _state_.parent_state = last_state
                states.append(_state_)


            elif _action_ in BETTING_ACTIONS:

                _state_.phase = 'BIDDING'
                _state_.agent.action = _action_
                _state_.agent.action_value = int(_action_[3:])
                _state_.agent.stack -= int(_action_[3:])
                _state_.pot += int(_action_[3:])

                _state_.nn_current_bidding += 1
                _state_.parent_state = last_state
                states.append(_state_)

            else:

                print('...unknown action...')
                exit()

        return states

    elif last_state.phase == 'BIDDING' and last_state.acting_agent == 'agent':

        states = []
        _state_ = copy_state(last_state)
        _state_.acting_agent = 'opponent'

        opponent_action, opponent_action_value = pe_.poker_strategy_example(last_state.opponent.current_hand_type[0],
                                                                            last_state.opponent.current_hand_type[1],
                                                                            last_state.opponent.stack,
                                                                            last_state.agent.action,
                                                                            last_state.agent.action_value,
                                                                            last_state.agent.stack,
                                                                            last_state.pot,
                                                                            last_state.nn_current_bidding)
        print()
        if opponent_action =='CALL':

            _state_.phase = 'SHOWDOWN'
            _state_.opponent.action = opponent_action
            _state_.opponent.action_value = 5
            _state_.opponent.stack -= 5
            _state_.pot += 5

            _state_.showdown()

            _state_.nn_current_hand += 1
            _state_.nn_current_bidding = 0
            _state_.pot = 0
            _state_.parent_state = last_state
            states.append(_state_)

        elif opponent_action == 'FOLD':

            _state_.phase = 'SHOWDOWN'

            _state_.opponent.action = opponent_action
            _state_.agent.stack += _state_.pot

            _state_.nn_current_hand += 1
            _state_.nn_current_bidding = 0
            _state_.pot = 0
            _state_.parent_state = last_state
            states.append(_state_)

        elif opponent_action + str(opponent_action_value) in BETTING_ACTIONS:

            _state_.phase = 'BIDDING'

            _state_.opponent.action = opponent_action
            _state_.opponent.action_value = opponent_action_value
            _state_.opponent.stack -= opponent_action_value
            _state_.pot += opponent_action_value

            _state_.nn_current_bidding += 1
            _state_.parent_state = last_state
            states.append(_state_)

        else:
            print('unknown_action')
            exit()
        return states




"""
Game flow:
Two agents will keep playing until one of them lose 100 coins or more.
"""

MAX_HANDS = 4
INIT_AGENT_STACK = 400

# initialize 2 agents and a game_state
agent = PokerPlayer(current_hand_=None, stack_=INIT_AGENT_STACK, action_=None, action_value_=None)
opponent = PokerPlayer(current_hand_=None, stack_=INIT_AGENT_STACK, action_=None, action_value_=None)


init_state = GameState(nn_current_hand_=0,
                       nn_current_bidding_=0,
                       phase_ = 'INIT_DEALING',
                       pot_=0,
                       acting_agent_=None,
                       agent_=agent,
                       opponent_=opponent,
                       )


game_state_queue = []
game_on = True
round_init = True

while game_on:

    if round_init:
        round_init = False
        states_ = get_next_states(init_state)
        game_state_queue.extend(states_[:])
    else:

        # just an example: only expanding the last return node
        states_ = get_next_states(states_[-1])
        game_state_queue.extend(states_[:])

        for _state_ in states_:
            if _state_.phase == 'SHOWDOWN' and (_state_.opponent.stack <= 300 or _state_.agent.stack <= 300): #or _state_.MAX_HANDS >= 4):
                    end_state_ = _state_
                    game_on = False

# %%
# print all states

state__ = end_state_
nn_level = 0

print('------------ print game info ---------------')
print('nn_states_total', len(game_state_queue))

while state__.parent_state != None:
    nn_level += 1
    print(nn_level)
    state__.print_state_info()
    state__ = state__.parent_state

print(nn_level)
# Out:
# ------------ print game info ---------------
# nn_states_total 200
# 1
# ************* state info **************
# nn_current_hand 40
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent agent
# parent_state <__main__.GameState object at 0x115da9a90>
# children None
# agent <__main__.PokerPlayer object at 0x115dab7b8>
# opponent <__main__.PokerPlayer object at 0x115dab828>
# ---------- showdown ----------
# agent.current_hand ['5s', '8d', '6c', 'Qc', '7c']
# ['HighCard', 'Q', 'c'] 24
# opponent.current_hand ['4s', 'Jc', '9h', 'Ah', 'Kc']
# ['HighCard', 'A', 'h'] 26
# showdown_info opponent win
# ----- agent -----
# agent.current_hand ['5s', '8d', '6c', 'Qc', '7c']
# agent.current_hand_type ['HighCard', 'Q', 'c']
# agent.current_hand_strength 24
# agent.stack 300.0
# agent.action CALL
# agent.action_value 5
# ----- opponent -----
# opponent.current_hand ['4s', 'Jc', '9h', 'Ah', 'Kc']
# opponent.current_hand_type ['HighCard', 'A', 'h']
# opponent.current_hand_strength 26
# opponent.stack 500.0
# opponent.action None
# opponent.action_value None
# **************** end ******************
# 2
# ************* state info **************
# nn_current_hand 39
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent agent
# parent_state <__main__.GameState object at 0x115da8898>
# children None
# agent <__main__.PokerPlayer object at 0x115da9ba8>
# opponent <__main__.PokerPlayer object at 0x115da9cc0>
# ---------- showdown ----------
# agent.current_hand ['9d', '8s', '7c', '7d', '2s']
# ['OnePair', '7', 'd'] 32
# opponent.current_hand ['Td', '9s', '6c', 'Th', '5d']
# ['OnePair', 'T', 'h'] 35
# showdown_info opponent win
# ----- agent -----
# agent.current_hand ['9d', '8s', '7c', '7d', '2s']
# agent.current_hand_type ['OnePair', '7', 'd']
# agent.current_hand_strength 32
# agent.stack 305.0
# agent.action CALL
# agent.action_value 5
# ----- opponent -----
# opponent.current_hand ['Td', '9s', '6c', 'Th', '5d']
# opponent.current_hand_type ['OnePair', 'T', 'h']
# opponent.current_hand_strength 35
# opponent.stack 495.0
# opponent.action None
# opponent.action_value None
# **************** end ******************
# 3
# ************* state info **************
# nn_current_hand 38
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent agent
# parent_state <__main__.GameState object at 0x115da8dd8>
# children None
# agent <__main__.PokerPlayer object at 0x115da8f98>
# opponent <__main__.PokerPlayer object at 0x115da7a58>
# ---------- showdown ----------
# agent.current_hand ['Jc', '3s', '6d', '9h', '4s']
# ['HighCard', 'J', 'c'] 23
# opponent.current_hand ['9c', '9s', 'Kc', 'Jh', '7d']
# ['OnePair', '9', 's'] 34
# showdown_info opponent win
# ----- agent -----
# agent.current_hand ['Jc', '3s', '6d', '9h', '4s']
# agent.current_hand_type ['HighCard', 'J', 'c']
# agent.current_hand_strength 23
# agent.stack 310.0
# agent.action CALL
# agent.action_value 5
# ----- opponent -----
# opponent.current_hand ['9c', '9s', 'Kc', 'Jh', '7d']
# opponent.current_hand_type ['OnePair', '9', 's']
# opponent.current_hand_strength 34
# opponent.stack 490.0
# opponent.action None
# opponent.action_value None
# **************** end ******************
# 4
# ************* state info **************
# nn_current_hand 37
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent agent
# parent_state <__main__.GameState object at 0x115da5cf8>
# children None
# agent <__main__.PokerPlayer object at 0x115da8e80>
# opponent <__main__.PokerPlayer object at 0x115da8ef0>
# ---------- showdown ----------
# agent.current_hand ['Ac', '4s', '5d', '3s', 'Th']
# ['HighCard', 'A', 'c'] 26
# opponent.current_hand ['Jc', '5c', 'Qc', '6h', 'Ad']
# ['HighCard', 'A', 'd'] 26
# showdown_info draw
# ----- agent -----
# agent.current_hand ['Ac', '4s', '5d', '3s', 'Th']
# agent.current_hand_type ['HighCard', 'A', 'c']
# agent.current_hand_strength 26
# agent.stack 315.0
# agent.action CALL
# agent.action_value 5
# ----- opponent -----
# opponent.current_hand ['Jc', '5c', 'Qc', '6h', 'Ad']
# opponent.current_hand_type ['HighCard', 'A', 'd']
# opponent.current_hand_strength 26
# opponent.stack 485.0
# opponent.action None
# opponent.action_value None
# **************** end ******************
# 5
# ************* state info **************
# nn_current_hand 36
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent agent
# parent_state <__main__.GameState object at 0x115d98860>
# children None
# agent <__main__.PokerPlayer object at 0x115da52b0>
# opponent <__main__.PokerPlayer object at 0x115da52e8>
# ---------- showdown ----------
# agent.current_hand ['4c', '4s', '3s', 'As', '4d']
# ['3OfAKind', '4', 'c'] 55
# opponent.current_hand ['Ah', '3c', '4h', '2c', '9s']
# ['HighCard', 'A', 'h'] 26
# showdown_info agent win
# ----- agent -----
# agent.current_hand ['4c', '4s', '3s', 'As', '4d']
# agent.current_hand_type ['3OfAKind', '4', 'c']
# agent.current_hand_strength 55
# agent.stack 315.0
# agent.action CALL
# agent.action_value 5
# ----- opponent -----
# opponent.current_hand ['Ah', '3c', '4h', '2c', '9s']
# opponent.current_hand_type ['HighCard', 'A', 'h']
# opponent.current_hand_strength 26
# opponent.stack 485.0
# opponent.action None
# opponent.action_value None
# **************** end ******************
# 6
# ************* state info **************
# nn_current_hand 35
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent agent
# parent_state <__main__.GameState object at 0x115d98198>
# children None
# agent <__main__.PokerPlayer object at 0x115d98940>
# opponent <__main__.PokerPlayer object at 0x115d98b38>
# ---------- showdown ----------
# agent.current_hand ['Ts', 'Qc', 'Ks', '8s', '2c']
# ['HighCard', 'K', 's'] 25
# opponent.current_hand ['3s', '4c', '4h', '7c', '9c']
# ['OnePair', '4', 'h'] 29
# showdown_info opponent win
# ----- agent -----
# agent.current_hand ['Ts', 'Qc', 'Ks', '8s', '2c']
# agent.current_hand_type ['HighCard', 'K', 's']
# agent.current_hand_strength 25
# agent.stack 315.0
# agent.action CALL
# agent.action_value 5
# ----- opponent -----
# opponent.current_hand ['3s', '4c', '4h', '7c', '9c']
# opponent.current_hand_type ['OnePair', '4', 'h']
# opponent.current_hand_strength 29
# opponent.stack 485.0
# opponent.action None
# opponent.action_value None
# **************** end ******************
# 7
# ************* state info **************
# nn_current_hand 34
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent agent
# parent_state <__main__.GameState object at 0x115d940b8>
# children None
# agent <__main__.PokerPlayer object at 0x115d982b0>
# opponent <__main__.PokerPlayer object at 0x115d982e8>
# ---------- showdown ----------
# agent.current_hand ['3d', 'Ah', '7c', '8s', 'Qc']
# ['HighCard', 'A', 'h'] 26
# opponent.current_hand ['5d', '7s', '5c', '8c', '6h']
# ['OnePair', '5', 'd'] 30
# showdown_info opponent win
# ----- agent -----
# agent.current_hand ['3d', 'Ah', '7c', '8s', 'Qc']
# agent.current_hand_type ['HighCard', 'A', 'h']
# agent.current_hand_strength 26
# agent.stack 320.0
# agent.action CALL
# agent.action_value 5
# ----- opponent -----
# opponent.current_hand ['5d', '7s', '5c', '8c', '6h']
# opponent.current_hand_type ['OnePair', '5', 'd']
# opponent.current_hand_strength 30
# opponent.stack 480.0
# opponent.action None
# opponent.action_value None
# **************** end ******************
# 8
# ************* state info **************
# nn_current_hand 33
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent agent
# parent_state <__main__.GameState object at 0x115d9bc88>
# children None
# agent <__main__.PokerPlayer object at 0x115d94198>
# opponent <__main__.PokerPlayer object at 0x115d941d0>
# ---------- showdown ----------
# agent.current_hand ['Ks', '8c', '6c', 'Kd', 'Kh']
# ['3OfAKind', 'K', 's'] 64
# opponent.current_hand ['5d', 'Qh', 'Js', '5h', 'Td']
# ['OnePair', '5', 'h'] 30
# showdown_info agent win
# ----- agent -----
# agent.current_hand ['Ks', '8c', '6c', 'Kd', 'Kh']
# agent.current_hand_type ['3OfAKind', 'K', 's']
# agent.current_hand_strength 64
# agent.stack 325.0
# agent.action CALL
# agent.action_value 5
# ----- opponent -----
# opponent.current_hand ['5d', 'Qh', 'Js', '5h', 'Td']
# opponent.current_hand_type ['OnePair', '5', 'h']
# opponent.current_hand_strength 30
# opponent.stack 475.0
# opponent.action None
# opponent.action_value None
# **************** end ******************
# 9
# ************* state info **************
# nn_current_hand 32
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent agent
# parent_state <__main__.GameState object at 0x115d8c208>
# children None
# agent <__main__.PokerPlayer object at 0x115d9bd30>
# opponent <__main__.PokerPlayer object at 0x115d9bd68>
# ---------- showdown ----------
# agent.current_hand ['4c', 'Ah', 'Jh', '2h', '5s']
# ['HighCard', 'A', 'h'] 26
# opponent.current_hand ['Js', '4d', 'Kd', 'Qd', 'Jd']
# ['OnePair', 'J', 's'] 36
# showdown_info opponent win
# ----- agent -----
# agent.current_hand ['4c', 'Ah', 'Jh', '2h', '5s']
# agent.current_hand_type ['HighCard', 'A', 'h']
# agent.current_hand_strength 26
# agent.stack 325.0
# agent.action CALL
# agent.action_value 5
# ----- opponent -----
# opponent.current_hand ['Js', '4d', 'Kd', 'Qd', 'Jd']
# opponent.current_hand_type ['OnePair', 'J', 's']
# opponent.current_hand_strength 36
# opponent.stack 475.0
# opponent.action None
# opponent.action_value None
# **************** end ******************
# 10
# ************* state info **************
# nn_current_hand 31
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent agent
# parent_state <__main__.GameState object at 0x115d86cc0>
# children None
# agent <__main__.PokerPlayer object at 0x115d8c748>
# opponent <__main__.PokerPlayer object at 0x115d8cc18>
# ---------- showdown ----------
# agent.current_hand ['Tc', 'Qh', 'Ah', '7h', '5d']
# ['HighCard', 'A', 'h'] 26
# opponent.current_hand ['Kd', 'Th', '3d', 'Jh', '5h']
# ['HighCard', 'K', 'd'] 25
# showdown_info agent win
# ----- agent -----
# agent.current_hand ['Tc', 'Qh', 'Ah', '7h', '5d']
# agent.current_hand_type ['HighCard', 'A', 'h']
# agent.current_hand_strength 26
# agent.stack 330.0
# agent.action CALL
# agent.action_value 5
# ----- opponent -----
# opponent.current_hand ['Kd', 'Th', '3d', 'Jh', '5h']
# opponent.current_hand_type ['HighCard', 'K', 'd']
# opponent.current_hand_strength 25
# opponent.stack 470.0
# opponent.action None
# opponent.action_value None
# **************** end ******************
# 11
# ************* state info **************
# nn_current_hand 30
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent agent
# parent_state <__main__.GameState object at 0x115d86e80>
# children None
# agent <__main__.PokerPlayer object at 0x115d86f60>
# opponent <__main__.PokerPlayer object at 0x115d86208>
# ---------- showdown ----------
# agent.current_hand ['6d', '8h', 'Kd', 'Ad', '3c']
# ['HighCard', 'A', 'd'] 26
# opponent.current_hand ['Ts', '4c', '7d', '6h', '4h']
# ['OnePair', '4', 'h'] 29
# showdown_info opponent win
# ----- agent -----
# agent.current_hand ['6d', '8h', 'Kd', 'Ad', '3c']
# agent.current_hand_type ['HighCard', 'A', 'd']
# agent.current_hand_strength 26
# agent.stack 330.0
# agent.action CALL
# agent.action_value 5
# ----- opponent -----
# opponent.current_hand ['Ts', '4c', '7d', '6h', '4h']
# opponent.current_hand_type ['OnePair', '4', 'h']
# opponent.current_hand_strength 29
# opponent.stack 470.0
# opponent.action None
# opponent.action_value None
# **************** end ******************
# 12
# ************* state info **************
# nn_current_hand 29
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent agent
# parent_state <__main__.GameState object at 0x115d854a8>
# children None
# agent <__main__.PokerPlayer object at 0x115d86c88>
# opponent <__main__.PokerPlayer object at 0x115d86048>
# ---------- showdown ----------
# agent.current_hand ['8h', 'Kd', 'Ts', '3s', '5c']
# ['HighCard', 'K', 'd'] 25
# opponent.current_hand ['2c', '7s', '3d', '5h', '4c']
# ['HighCard', '7', 's'] 19
# showdown_info agent win
# ----- agent -----
# agent.current_hand ['8h', 'Kd', 'Ts', '3s', '5c']
# agent.current_hand_type ['HighCard', 'K', 'd']
# agent.current_hand_strength 25
# agent.stack 335.0
# agent.action CALL
# agent.action_value 5
# ----- opponent -----
# opponent.current_hand ['2c', '7s', '3d', '5h', '4c']
# opponent.current_hand_type ['HighCard', '7', 's']
# opponent.current_hand_strength 19
# opponent.stack 465.0
# opponent.action None
# opponent.action_value None
# **************** end ******************
# 13
# ************* state info **************
# nn_current_hand 28
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent agent
# parent_state <__main__.GameState object at 0x115d7f748>
# children None
# agent <__main__.PokerPlayer object at 0x115d856a0>
# opponent <__main__.PokerPlayer object at 0x115d85a20>
# ---------- showdown ----------
# agent.current_hand ['6h', 'Ks', '7s', 'Ad', 'Qd']
# ['HighCard', 'A', 'd'] 26
# opponent.current_hand ['4d', 'Kd', '2s', '8s', '9h']
# ['HighCard', 'K', 'd'] 25
# showdown_info agent win
# ----- agent -----
# agent.current_hand ['6h', 'Ks', '7s', 'Ad', 'Qd']
# agent.current_hand_type ['HighCard', 'A', 'd']
# agent.current_hand_strength 26
# agent.stack 335.0
# agent.action CALL
# agent.action_value 5
# ----- opponent -----
# opponent.current_hand ['4d', 'Kd', '2s', '8s', '9h']
# opponent.current_hand_type ['HighCard', 'K', 'd']
# opponent.current_hand_strength 25
# opponent.stack 465.0
# opponent.action None
# opponent.action_value None
# **************** end ******************
# 14
# ************* state info **************
# nn_current_hand 27
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent agent
# parent_state <__main__.GameState object at 0x115d7cc88>
# children None
# agent <__main__.PokerPlayer object at 0x115d7f9e8>
# opponent <__main__.PokerPlayer object at 0x115d7ffd0>
# ---------- showdown ----------
# agent.current_hand ['Jd', '6h', 'Jc', '4c', '9c']
# ['OnePair', 'J', 'd'] 36
# opponent.current_hand ['7d', '9h', '2d', '9s', '6s']
# ['OnePair', '9', 's'] 34
# showdown_info agent win
# ----- agent -----
# agent.current_hand ['Jd', '6h', 'Jc', '4c', '9c']
# agent.current_hand_type ['OnePair', 'J', 'd']
# agent.current_hand_strength 36
# agent.stack 335.0
# agent.action CALL
# agent.action_value 5
# ----- opponent -----
# opponent.current_hand ['7d', '9h', '2d', '9s', '6s']
# opponent.current_hand_type ['OnePair', '9', 's']
# opponent.current_hand_strength 34
# opponent.stack 465.0
# opponent.action None
# opponent.action_value None
# **************** end ******************
# 15
# ************* state info **************
# nn_current_hand 26
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent agent
# parent_state <__main__.GameState object at 0x115d78ef0>
# children None
# agent <__main__.PokerPlayer object at 0x115d7e470>
# opponent <__main__.PokerPlayer object at 0x115d7e390>
# ---------- showdown ----------
# agent.current_hand ['As', '7s', 'Ah', 'Td', '8h']
# ['OnePair', 'A', 's'] 39
# opponent.current_hand ['4d', 'Jh', '7h', '7d', '9d']
# ['OnePair', '7', 'h'] 32
# showdown_info agent win
# ----- agent -----
# agent.current_hand ['As', '7s', 'Ah', 'Td', '8h']
# agent.current_hand_type ['OnePair', 'A', 's']
# agent.current_hand_strength 39
# agent.stack 335.0
# agent.action CALL
# agent.action_value 5
# ----- opponent -----
# opponent.current_hand ['4d', 'Jh', '7h', '7d', '9d']
# opponent.current_hand_type ['OnePair', '7', 'h']
# opponent.current_hand_strength 32
# opponent.stack 465.0
# opponent.action None
# opponent.action_value None
# **************** end ******************
# 16
# ************* state info **************
# nn_current_hand 25
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent agent
# parent_state <__main__.GameState object at 0x115d7c2b0>
# children None
# agent <__main__.PokerPlayer object at 0x115d78748>
# opponent <__main__.PokerPlayer object at 0x115d78cc0>
# ---------- showdown ----------
# agent.current_hand ['Kh', 'Ts', '5s', 'Jd', '7d']
# ['HighCard', 'K', 'h'] 25
# opponent.current_hand ['Ah', 'Ad', 'As', 'Tc', 'Th']
# ['FullHouse', 'A', 'h'] 104
# showdown_info opponent win
# ----- agent -----
# agent.current_hand ['Kh', 'Ts', '5s', 'Jd', '7d']
# agent.current_hand_type ['HighCard', 'K', 'h']
# agent.current_hand_strength 25
# agent.stack 335.0
# agent.action CALL
# agent.action_value 5
# ----- opponent -----
# opponent.current_hand ['Ah', 'Ad', 'As', 'Tc', 'Th']
# opponent.current_hand_type ['FullHouse', 'A', 'h']
# opponent.current_hand_strength 104
# opponent.stack 465.0
# opponent.action None
# opponent.action_value None
# **************** end ******************
# 17
# ************* state info **************
# nn_current_hand 24
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent agent
# parent_state <__main__.GameState object at 0x115d756d8>
# children None
# agent <__main__.PokerPlayer object at 0x115d7c080>
# opponent <__main__.PokerPlayer object at 0x115d7c470>
# ---------- showdown ----------
# agent.current_hand ['8h', '2h', '3d', '9d', 'Qc']
# ['HighCard', 'Q', 'c'] 24
# opponent.current_hand ['Ts', '8d', '2c', 'Kd', 'Kh']
# ['OnePair', 'K', 'h'] 38
# showdown_info opponent win
# ----- agent -----
# agent.current_hand ['8h', '2h', '3d', '9d', 'Qc']
# agent.current_hand_type ['HighCard', 'Q', 'c']
# agent.current_hand_strength 24
# agent.stack 340.0
# agent.action CALL
# agent.action_value 5
# ----- opponent -----
# opponent.current_hand ['Ts', '8d', '2c', 'Kd', 'Kh']
# opponent.current_hand_type ['OnePair', 'K', 'h']
# opponent.current_hand_strength 38
# opponent.stack 460.0
# opponent.action None
# opponent.action_value None
# **************** end ******************
# 18
# ************* state info **************
# nn_current_hand 23
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent agent
# parent_state <__main__.GameState object at 0x115d725c0>
# children None
# agent <__main__.PokerPlayer object at 0x115d75390>
# opponent <__main__.PokerPlayer object at 0x115d75f28>
# ---------- showdown ----------
# agent.current_hand ['6d', 'Qs', '7s', '9h', 'Tc']
# ['HighCard', 'Q', 's'] 24
# opponent.current_hand ['Ah', '2s', 'Jh', '9d', 'As']
# ['OnePair', 'A', 's'] 39
# showdown_info opponent win
# ----- agent -----
# agent.current_hand ['6d', 'Qs', '7s', '9h', 'Tc']
# agent.current_hand_type ['HighCard', 'Q', 's']
# agent.current_hand_strength 24
# agent.stack 345.0
# agent.action CALL
# agent.action_value 5
# ----- opponent -----
# opponent.current_hand ['Ah', '2s', 'Jh', '9d', 'As']
# opponent.current_hand_type ['OnePair', 'A', 's']
# opponent.current_hand_strength 39
# opponent.stack 455.0
# opponent.action None
# opponent.action_value None
# **************** end ******************
# 19
# ************* state info **************
# nn_current_hand 22
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent agent
# parent_state <__main__.GameState object at 0x115d71f28>
# children None
# agent <__main__.PokerPlayer object at 0x115d72278>
# opponent <__main__.PokerPlayer object at 0x115d72eb8>
# ---------- showdown ----------
# agent.current_hand ['2c', 'Tc', '7s', '8s', 'Td']
# ['OnePair', 'T', 'd'] 35
# opponent.current_hand ['7d', '3d', '3c', '9s', '7c']
# ['TwoPairs', '7', 'c'] 45
# showdown_info opponent win
# ----- agent -----
# agent.current_hand ['2c', 'Tc', '7s', '8s', 'Td']
# agent.current_hand_type ['OnePair', 'T', 'd']
# agent.current_hand_strength 35
# agent.stack 350.0
# agent.action CALL
# agent.action_value 5
# ----- opponent -----
# opponent.current_hand ['7d', '3d', '3c', '9s', '7c']
# opponent.current_hand_type ['TwoPairs', '7', 'c']
# opponent.current_hand_strength 45
# opponent.stack 450.0
# opponent.action None
# opponent.action_value None
# **************** end ******************
# 20
# ************* state info **************
# nn_current_hand 21
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent agent
# parent_state <__main__.GameState object at 0x115d71e48>
# children None
# agent <__main__.PokerPlayer object at 0x115d71908>
# opponent <__main__.PokerPlayer object at 0x115d72710>
# ---------- showdown ----------
# agent.current_hand ['3c', '6d', 'Qc', 'Ac', 'Ks']
# ['HighCard', 'A', 'c'] 26
# opponent.current_hand ['6s', 'Ad', 'Td', '3s', '7d']
# ['HighCard', 'A', 'd'] 26
# showdown_info draw
# ----- agent -----
# agent.current_hand ['3c', '6d', 'Qc', 'Ac', 'Ks']
# agent.current_hand_type ['HighCard', 'A', 'c']
# agent.current_hand_strength 26
# agent.stack 355.0
# agent.action CALL
# agent.action_value 5
# ----- opponent -----
# opponent.current_hand ['6s', 'Ad', 'Td', '3s', '7d']
# opponent.current_hand_type ['HighCard', 'A', 'd']
# opponent.current_hand_strength 26
# opponent.stack 445.0
# opponent.action None
# opponent.action_value None
# **************** end ******************
# 21
# ************* state info **************
# nn_current_hand 20
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent agent
# parent_state <__main__.GameState object at 0x1095fc908>
# children None
# agent <__main__.PokerPlayer object at 0x115d717f0>
# opponent <__main__.PokerPlayer object at 0x115d71668>
# ---------- showdown ----------
# agent.current_hand ['Kc', '4s', 'Ks', 'Qd', 'Jd']
# ['OnePair', 'K', 's'] 38
# opponent.current_hand ['Js', '3h', '6s', '8d', '2s']
# ['HighCard', 'J', 's'] 23
# showdown_info agent win
# ----- agent -----
# agent.current_hand ['Kc', '4s', 'Ks', 'Qd', 'Jd']
# agent.current_hand_type ['OnePair', 'K', 's']
# agent.current_hand_strength 38
# agent.stack 355.0
# agent.action CALL
# agent.action_value 5
# ----- opponent -----
# opponent.current_hand ['Js', '3h', '6s', '8d', '2s']
# opponent.current_hand_type ['HighCard', 'J', 's']
# opponent.current_hand_strength 23
# opponent.stack 445.0
# opponent.action None
# opponent.action_value None
# **************** end ******************
# 22
# ************* state info **************
# nn_current_hand 19
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent agent
# parent_state <__main__.GameState object at 0x1095fba90>
# children None
# agent <__main__.PokerPlayer object at 0x1095fc198>
# opponent <__main__.PokerPlayer object at 0x1095fcb00>
# ---------- showdown ----------
# agent.current_hand ['4h', '3c', 'Jh', '8h', 'Th']
# ['HighCard', 'J', 'h'] 23
# opponent.current_hand ['9h', 'Qs', 'Jd', '2c', 'Ts']
# ['HighCard', 'Q', 's'] 24
# showdown_info opponent win
# ----- agent -----
# agent.current_hand ['4h', '3c', 'Jh', '8h', 'Th']
# agent.current_hand_type ['HighCard', 'J', 'h']
# agent.current_hand_strength 23
# agent.stack 355.0
# agent.action CALL
# agent.action_value 5
# ----- opponent -----
# opponent.current_hand ['9h', 'Qs', 'Jd', '2c', 'Ts']
# opponent.current_hand_type ['HighCard', 'Q', 's']
# opponent.current_hand_strength 24
# opponent.stack 445.0
# opponent.action None
# opponent.action_value None
# **************** end ******************
# 23
# ************* state info **************
# nn_current_hand 18
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent agent
# parent_state <__main__.GameState object at 0x1095fb390>
# children None
# agent <__main__.PokerPlayer object at 0x1095fb978>
# opponent <__main__.PokerPlayer object at 0x1095fb048>
# ---------- showdown ----------
# agent.current_hand ['6d', '8c', '2s', 'Kc', '9d']
# ['HighCard', 'K', 'c'] 25
# opponent.current_hand ['Ad', 'Qh', '6h', '4s', '4c']
# ['OnePair', '4', 's'] 29
# showdown_info opponent win
# ----- agent -----
# agent.current_hand ['6d', '8c', '2s', 'Kc', '9d']
# agent.current_hand_type ['HighCard', 'K', 'c']
# agent.current_hand_strength 25
# agent.stack 360.0
# agent.action CALL
# agent.action_value 5
# ----- opponent -----
# opponent.current_hand ['Ad', 'Qh', '6h', '4s', '4c']
# opponent.current_hand_type ['OnePair', '4', 's']
# opponent.current_hand_strength 29
# opponent.stack 440.0
# opponent.action None
# opponent.action_value None
# **************** end ******************
# 24
# ************* state info **************
# nn_current_hand 17
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent agent
# parent_state <__main__.GameState object at 0x1095f7eb8>
# children None
# agent <__main__.PokerPlayer object at 0x1095fb550>
# opponent <__main__.PokerPlayer object at 0x1095fb0f0>
# ---------- showdown ----------
# agent.current_hand ['8h', 'Jc', '8s', '6c', '3s']
# ['OnePair', '8', 's'] 33
# opponent.current_hand ['7h', 'Td', 'Th', '9h', '7d']
# ['TwoPairs', 'T', 'h'] 48
# showdown_info opponent win
# ----- agent -----
# agent.current_hand ['8h', 'Jc', '8s', '6c', '3s']
# agent.current_hand_type ['OnePair', '8', 's']
# agent.current_hand_strength 33
# agent.stack 365.0
# agent.action CALL
# agent.action_value 5
# ----- opponent -----
# opponent.current_hand ['7h', 'Td', 'Th', '9h', '7d']
# opponent.current_hand_type ['TwoPairs', 'T', 'h']
# opponent.current_hand_strength 48
# opponent.stack 435.0
# opponent.action None
# opponent.action_value None
# **************** end ******************
# 25
# ************* state info **************
# nn_current_hand 16
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent agent
# parent_state <__main__.GameState object at 0x1095f2908>
# children None
# agent <__main__.PokerPlayer object at 0x1095f7e48>
# opponent <__main__.PokerPlayer object at 0x1095f7358>
# ---------- showdown ----------
# agent.current_hand ['2s', '2c', 'Ah', 'Th', '9h']
# ['OnePair', '2', 's'] 27
# opponent.current_hand ['7s', '6s', 'Qc', '9d', 'Jc']
# ['HighCard', 'Q', 'c'] 24
# showdown_info agent win
# ----- agent -----
# agent.current_hand ['2s', '2c', 'Ah', 'Th', '9h']
# agent.current_hand_type ['OnePair', '2', 's']
# agent.current_hand_strength 27
# agent.stack 370.0
# agent.action CALL
# agent.action_value 5
# ----- opponent -----
# opponent.current_hand ['7s', '6s', 'Qc', '9d', 'Jc']
# opponent.current_hand_type ['HighCard', 'Q', 'c']
# opponent.current_hand_strength 24
# opponent.stack 430.0
# opponent.action None
# opponent.action_value None
# **************** end ******************
# 26
# ************* state info **************
# nn_current_hand 15
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent agent
# parent_state <__main__.GameState object at 0x1095f20b8>
# children None
# agent <__main__.PokerPlayer object at 0x1095f2b70>
# opponent <__main__.PokerPlayer object at 0x1095f2978>
# ---------- showdown ----------
# agent.current_hand ['8s', '9d', '2c', '8c', '2d']
# ['TwoPairs', '8', 's'] 46
# opponent.current_hand ['3d', 'Jh', 'Ah', 'Th', '3c']
# ['OnePair', '3', 'd'] 28
# showdown_info agent win
# ----- agent -----
# agent.current_hand ['8s', '9d', '2c', '8c', '2d']
# agent.current_hand_type ['TwoPairs', '8', 's']
# agent.current_hand_strength 46
# agent.stack 370.0
# agent.action CALL
# agent.action_value 5
# ----- opponent -----
# opponent.current_hand ['3d', 'Jh', 'Ah', 'Th', '3c']
# opponent.current_hand_type ['OnePair', '3', 'd']
# opponent.current_hand_strength 28
# opponent.stack 430.0
# opponent.action None
# opponent.action_value None
# **************** end ******************
# 27
# ************* state info **************
# nn_current_hand 14
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent agent
# parent_state <__main__.GameState object at 0x1095f0080>
# children None
# agent <__main__.PokerPlayer object at 0x1095f2898>
# opponent <__main__.PokerPlayer object at 0x1095f2a20>
# ---------- showdown ----------
# agent.current_hand ['6h', '7d', '4s', '8d', '6d']
# ['OnePair', '6', 'h'] 31
# opponent.current_hand ['7s', '7c', 'Th', 'Ac', 'Tc']
# ['TwoPairs', 'T', 'h'] 48
# showdown_info opponent win
# ----- agent -----
# agent.current_hand ['6h', '7d', '4s', '8d', '6d']
# agent.current_hand_type ['OnePair', '6', 'h']
# agent.current_hand_strength 31
# agent.stack 370.0
# agent.action CALL
# agent.action_value 5
# ----- opponent -----
# opponent.current_hand ['7s', '7c', 'Th', 'Ac', 'Tc']
# opponent.current_hand_type ['TwoPairs', 'T', 'h']
# opponent.current_hand_strength 48
# opponent.stack 430.0
# opponent.action None
# opponent.action_value None
# **************** end ******************
# 28
# ************* state info **************
# nn_current_hand 13
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent agent
# parent_state <__main__.GameState object at 0x1095ec518>
# children None
# agent <__main__.PokerPlayer object at 0x1095f09e8>
# opponent <__main__.PokerPlayer object at 0x1095f09b0>
# ---------- showdown ----------
# agent.current_hand ['5s', 'Qs', '4d', 'Qh', '9h']
# ['OnePair', 'Q', 's'] 37
# opponent.current_hand ['Kh', '8h', '2c', 'Th', '9d']
# ['HighCard', 'K', 'h'] 25
# showdown_info agent win
# ----- agent -----
# agent.current_hand ['5s', 'Qs', '4d', 'Qh', '9h']
# agent.current_hand_type ['OnePair', 'Q', 's']
# agent.current_hand_strength 37
# agent.stack 375.0
# agent.action CALL
# agent.action_value 5
# ----- opponent -----
# opponent.current_hand ['Kh', '8h', '2c', 'Th', '9d']
# opponent.current_hand_type ['HighCard', 'K', 'h']
# opponent.current_hand_strength 25
# opponent.stack 425.0
# opponent.action None
# opponent.action_value None
# **************** end ******************
# 29
# ************* state info **************
# nn_current_hand 12
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent agent
# parent_state <__main__.GameState object at 0x1095e9470>
# children None
# agent <__main__.PokerPlayer object at 0x1095ec160>
# opponent <__main__.PokerPlayer object at 0x1095ecf28>
# ---------- showdown ----------
# agent.current_hand ['Tc', 'Ac', '8d', 'As', '3d']
# ['OnePair', 'A', 's'] 39
# opponent.current_hand ['8s', '8c', 'Ad', 'Th', 'Kc']
# ['OnePair', '8', 's'] 33
# showdown_info agent win
# ----- agent -----
# agent.current_hand ['Tc', 'Ac', '8d', 'As', '3d']
# agent.current_hand_type ['OnePair', 'A', 's']
# agent.current_hand_strength 39
# agent.stack 375.0
# agent.action CALL
# agent.action_value 5
# ----- opponent -----
# opponent.current_hand ['8s', '8c', 'Ad', 'Th', 'Kc']
# opponent.current_hand_type ['OnePair', '8', 's']
# opponent.current_hand_strength 33
# opponent.stack 425.0
# opponent.action None
# opponent.action_value None
# **************** end ******************
# 30
# ************* state info **************
# nn_current_hand 11
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent agent
# parent_state <__main__.GameState object at 0x1095e48d0>
# children None
# agent <__main__.PokerPlayer object at 0x1095e9cc0>
# opponent <__main__.PokerPlayer object at 0x1095e96a0>
# ---------- showdown ----------
# agent.current_hand ['8c', 'Qh', '7c', '5d', '6c']
# ['HighCard', 'Q', 'h'] 24
# opponent.current_hand ['Jd', '5c', 'Qc', '7d', 'Qs']
# ['OnePair', 'Q', 's'] 37
# showdown_info opponent win
# ----- agent -----
# agent.current_hand ['8c', 'Qh', '7c', '5d', '6c']
# agent.current_hand_type ['HighCard', 'Q', 'h']
# agent.current_hand_strength 24
# agent.stack 375.0
# agent.action CALL
# agent.action_value 5
# ----- opponent -----
# opponent.current_hand ['Jd', '5c', 'Qc', '7d', 'Qs']
# opponent.current_hand_type ['OnePair', 'Q', 's']
# opponent.current_hand_strength 37
# opponent.stack 425.0
# opponent.action None
# opponent.action_value None
# **************** end ******************
# 31
# ************* state info **************
# nn_current_hand 10
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent agent
# parent_state <__main__.GameState object at 0x1095e6278>
# children None
# agent <__main__.PokerPlayer object at 0x1095e6be0>
# opponent <__main__.PokerPlayer object at 0x1095e6f60>
# ---------- showdown ----------
# agent.current_hand ['6c', 'Ad', 'Qh', '3h', 'Kd']
# ['HighCard', 'A', 'd'] 26
# opponent.current_hand ['2s', '2c', '9c', '4s', 'Ts']
# ['OnePair', '2', 's'] 27
# showdown_info opponent win
# ----- agent -----
# agent.current_hand ['6c', 'Ad', 'Qh', '3h', 'Kd']
# agent.current_hand_type ['HighCard', 'A', 'd']
# agent.current_hand_strength 26
# agent.stack 380.0
# agent.action CALL
# agent.action_value 5
# ----- opponent -----
# opponent.current_hand ['2s', '2c', '9c', '4s', 'Ts']
# opponent.current_hand_type ['OnePair', '2', 's']
# opponent.current_hand_strength 27
# opponent.stack 420.0
# opponent.action None
# opponent.action_value None
# **************** end ******************
# 32
# ************* state info **************
# nn_current_hand 9
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent agent
# parent_state <__main__.GameState object at 0x1095e1588>
# children None
# agent <__main__.PokerPlayer object at 0x1095e61d0>
# opponent <__main__.PokerPlayer object at 0x1095e62e8>
# ---------- showdown ----------
# agent.current_hand ['8s', '6d', '9h', '5s', '6c']
# ['OnePair', '6', 'd'] 31
# opponent.current_hand ['Kd', '2c', '9s', '6h', '4h']
# ['HighCard', 'K', 'd'] 25
# showdown_info agent win
# ----- agent -----
# agent.current_hand ['8s', '6d', '9h', '5s', '6c']
# agent.current_hand_type ['OnePair', '6', 'd']
# agent.current_hand_strength 31
# agent.stack 385.0
# agent.action CALL
# agent.action_value 5
# ----- opponent -----
# opponent.current_hand ['Kd', '2c', '9s', '6h', '4h']
# opponent.current_hand_type ['HighCard', 'K', 'd']
# opponent.current_hand_strength 25
# opponent.stack 415.0
# opponent.action None
# opponent.action_value None
# **************** end ******************
# 33
# ************* state info **************
# nn_current_hand 8
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent agent
# parent_state <__main__.GameState object at 0x1095df6d8>
# children None
# agent <__main__.PokerPlayer object at 0x1095e3240>
# opponent <__main__.PokerPlayer object at 0x1095e3dd8>
# ---------- showdown ----------
# agent.current_hand ['Jh', 'Qs', '3c', '9h', '8c']
# ['HighCard', 'Q', 's'] 24
# opponent.current_hand ['As', '4d', '6d', '9c', '2d']
# ['HighCard', 'A', 's'] 26
# showdown_info opponent win
# ----- agent -----
# agent.current_hand ['Jh', 'Qs', '3c', '9h', '8c']
# agent.current_hand_type ['HighCard', 'Q', 's']
# agent.current_hand_strength 24
# agent.stack 385.0
# agent.action CALL
# agent.action_value 5
# ----- opponent -----
# opponent.current_hand ['As', '4d', '6d', '9c', '2d']
# opponent.current_hand_type ['HighCard', 'A', 's']
# opponent.current_hand_strength 26
# opponent.stack 415.0
# opponent.action None
# opponent.action_value None
# **************** end ******************
# 34
# ************* state info **************
# nn_current_hand 7
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent agent
# parent_state <__main__.GameState object at 0x1095dd9e8>
# children None
# agent <__main__.PokerPlayer object at 0x1095df208>
# opponent <__main__.PokerPlayer object at 0x1095e1240>
# ---------- showdown ----------
# agent.current_hand ['Qd', '2h', 'Td', '8s', '2d']
# ['OnePair', '2', 'h'] 27
# opponent.current_hand ['2c', '7c', '8d', '2s', '5d']
# ['OnePair', '2', 's'] 27
# showdown_info draw
# ----- agent -----
# agent.current_hand ['Qd', '2h', 'Td', '8s', '2d']
# agent.current_hand_type ['OnePair', '2', 'h']
# agent.current_hand_strength 27
# agent.stack 390.0
# agent.action CALL
# agent.action_value 5
# ----- opponent -----
# opponent.current_hand ['2c', '7c', '8d', '2s', '5d']
# opponent.current_hand_type ['OnePair', '2', 's']
# opponent.current_hand_strength 27
# opponent.stack 410.0
# opponent.action None
# opponent.action_value None
# **************** end ******************
# 35
# ************* state info **************
# nn_current_hand 6
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent agent
# parent_state <__main__.GameState object at 0x1095dde80>
# children None
# agent <__main__.PokerPlayer object at 0x1095dde10>
# opponent <__main__.PokerPlayer object at 0x1095ddf28>
# ---------- showdown ----------
# agent.current_hand ['5c', '6c', '4h', 'Jc', '7s']
# ['HighCard', 'J', 'c'] 23
# opponent.current_hand ['6h', '4s', '2h', '6s', 'Th']
# ['OnePair', '6', 's'] 31
# showdown_info opponent win
# ----- agent -----
# agent.current_hand ['5c', '6c', '4h', 'Jc', '7s']
# agent.current_hand_type ['HighCard', 'J', 'c']
# agent.current_hand_strength 23
# agent.stack 390
# agent.action CALL
# agent.action_value 5
# ----- opponent -----
# opponent.current_hand ['6h', '4s', '2h', '6s', 'Th']
# opponent.current_hand_type ['OnePair', '6', 's']
# opponent.current_hand_strength 31
# opponent.stack 410
# opponent.action None
# opponent.action_value None
# **************** end ******************
# 36
# ************* state info **************
# nn_current_hand 5
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent agent
# parent_state <__main__.GameState object at 0x1095dab00>
# children None
# agent <__main__.PokerPlayer object at 0x1095dd7b8>
# opponent <__main__.PokerPlayer object at 0x1095ddf60>
# ---------- showdown ----------
# agent.current_hand ['8d', '5s', '4s', '5c', 'Ks']
# ['OnePair', '5', 's'] 30
# opponent.current_hand ['5h', '3h', '9d', '7c', 'Ah']
# ['HighCard', 'A', 'h'] 26
# showdown_info agent win
# ----- agent -----
# agent.current_hand ['8d', '5s', '4s', '5c', 'Ks']
# agent.current_hand_type ['OnePair', '5', 's']
# agent.current_hand_strength 30
# agent.stack 395
# agent.action CALL
# agent.action_value 5
# ----- opponent -----
# opponent.current_hand ['5h', '3h', '9d', '7c', 'Ah']
# opponent.current_hand_type ['HighCard', 'A', 'h']
# opponent.current_hand_strength 26
# opponent.stack 405
# opponent.action None
# opponent.action_value None
# **************** end ******************
# 37
# ************* state info **************
# nn_current_hand 4
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent agent
# parent_state <__main__.GameState object at 0x1095d28d0>
# children None
# agent <__main__.PokerPlayer object at 0x1095da780>
# opponent <__main__.PokerPlayer object at 0x1095dabe0>
# ---------- showdown ----------
# agent.current_hand ['8d', '5s', '8c', '4s', 'Jc']
# ['OnePair', '8', 'd'] 33
# opponent.current_hand ['6s', '9h', '7h', '6h', '3h']
# ['OnePair', '6', 's'] 31
# showdown_info agent win
# ----- agent -----
# agent.current_hand ['8d', '5s', '8c', '4s', 'Jc']
# agent.current_hand_type ['OnePair', '8', 'd']
# agent.current_hand_strength 33
# agent.stack 395
# agent.action CALL
# agent.action_value 5
# ----- opponent -----
# opponent.current_hand ['6s', '9h', '7h', '6h', '3h']
# opponent.current_hand_type ['OnePair', '6', 's']
# opponent.current_hand_strength 31
# opponent.stack 405
# opponent.action None
# opponent.action_value None
# **************** end ******************
# 38
# ************* state info **************
# nn_current_hand 3
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent agent
# parent_state <__main__.GameState object at 0x1095d54a8>
# children None
# agent <__main__.PokerPlayer object at 0x1095d5198>
# opponent <__main__.PokerPlayer object at 0x1095d5518>
# ---------- showdown ----------
# agent.current_hand ['4s', '8s', 'Qd', '8d', '7c']
# ['OnePair', '8', 's'] 33
# opponent.current_hand ['Jh', '7s', 'Qs', '4d', '8c']
# ['HighCard', 'Q', 's'] 24
# showdown_info agent win
# ----- agent -----
# agent.current_hand ['4s', '8s', 'Qd', '8d', '7c']
# agent.current_hand_type ['OnePair', '8', 's']
# agent.current_hand_strength 33
# agent.stack 395
# agent.action CALL
# agent.action_value 5
# ----- opponent -----
# opponent.current_hand ['Jh', '7s', 'Qs', '4d', '8c']
# opponent.current_hand_type ['HighCard', 'Q', 's']
# opponent.current_hand_strength 24
# opponent.stack 405
# opponent.action None
# opponent.action_value None
# **************** end ******************
# 39
# ************* state info **************
# nn_current_hand 2
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent agent
# parent_state <__main__.GameState object at 0x1095d20f0>
# children None
# agent <__main__.PokerPlayer object at 0x1095d5278>
# opponent <__main__.PokerPlayer object at 0x1095d57f0>
# ---------- showdown ----------
# agent.current_hand ['2d', '2s', 'Ad', 'Kh', 'Js']
# ['OnePair', '2', 's'] 27
# opponent.current_hand ['Ah', 'Jc', '9s', 'Jh', '3s']
# ['OnePair', 'J', 'h'] 36
# showdown_info opponent win
# ----- agent -----
# agent.current_hand ['2d', '2s', 'Ad', 'Kh', 'Js']
# agent.current_hand_type ['OnePair', '2', 's']
# agent.current_hand_strength 27
# agent.stack 395
# agent.action CALL
# agent.action_value 5
# ----- opponent -----
# opponent.current_hand ['Ah', 'Jc', '9s', 'Jh', '3s']
# opponent.current_hand_type ['OnePair', 'J', 'h']
# opponent.current_hand_strength 36
# opponent.stack 405
# opponent.action None
# opponent.action_value None
# **************** end ******************
# 40
# ************* state info **************
# nn_current_hand 1
# nn_current_bidding 0
# phase SHOWDOWN
# pot 0
# acting_agent agent
# parent_state <__main__.GameState object at 0x115d9bcc0>
# children None
# agent <__main__.PokerPlayer object at 0x1095d2710>
# opponent <__main__.PokerPlayer object at 0x1095d2630>
# ---------- showdown ----------
# agent.current_hand ['Jc', 'Ac', 'Tc', 'Kd', 'Kh']
# ['OnePair', 'K', 'h'] 38
# opponent.current_hand ['Qd', '7c', '4s', '9h', '3d']
# ['HighCard', 'Q', 'd'] 24
# showdown_info agent win
# ----- agent -----
# agent.current_hand ['Jc', 'Ac', 'Tc', 'Kd', 'Kh']
# agent.current_hand_type ['OnePair', 'K', 'h']
# agent.current_hand_strength 38
# agent.stack 400
# agent.action CALL
# agent.action_value 5
# ----- opponent -----
# opponent.current_hand ['Qd', '7c', '4s', '9h', '3d']
# opponent.current_hand_type ['HighCard', 'Q', 'd']
# opponent.current_hand_strength 24
# opponent.stack 400
# opponent.action None
# opponent.action_value None
# **************** end ******************
# 40

# %%
# perform your searching algorithm
